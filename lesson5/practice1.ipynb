# %%
print {"HELLO, PYTHON"}
# Out:
#   Cell In[1], line 1
#     print {"HELLO, PYTHON"}
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ("hello! python")
# Out:
# hello! python

# %%
a = 13
if a >= 14:
    a-= 2
else:
    a += 2
    print(a)
# Out:
# 15
