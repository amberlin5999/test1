# %%
異常處理 (try-except) 與資料驗證

# %%
輸入格式錯誤，請輸入整數數字！

# %%
money = int(input("請輸入金額:"))
print("輸入的金額為:", money)
# Out:
# 請輸入金額: 100A
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 money = int(input("請輸入金額:"))
#       2 print("輸入的金額為:", money)
#
# ValueError: invalid literal for int() with base 10: '100A'

# %%
try:
    money = int(input("請輸入金額:"))
    print("輸入的金額為:", money)
except ValueError:
    print("輸入格式錯誤，請輸入整數數字！")
except:
    print("不知明的錯誤")
# Out:
# 請輸入金額: 100A
# 輸入格式錯誤，請輸入整數數字！
